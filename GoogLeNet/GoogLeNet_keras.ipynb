# %%
# importing libraries
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers.core import Dense, Activation, Dropout
from keras.layers import Flatten, Input, concatenate
from keras.models import Model
from keras.regularizers import l2
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
class GoogLeNet:
  @staticmethod
  def conv_module(x, K, kX, kY, stride, chanDim, padding = "same", reg = 0.0005, name = None):
    
    # initialize the CONV, BN, and RELU layer names
    (convName, bnName, actName) = (None, None, None)
    
    # if a layer name was supplied, prepend it
    if name is not None:
      convName = name + "_conv"
      bnName = name + "_bn"
      actName = name + "_act"
    
    # define a CONV => BN => RELU pattern
    x = Conv2D(K, (kX, kY), strides = stride, padding = padding, kernel_regularizer = l2(reg), name = convName)(x)
    x = BatchNormalization(axis = chanDim, name = bnName)(x)
    x = Activation("relu", name = actName)(x)
    
    # return the block
    return x
  
  @staticmethod
  def inception_module(x, num1x1, num3x3Reduce, num3x3, num5x5Reduce, num5x5, num1x1Proj, chanDim, stage, reg = 0.0005):
    
    # define the first branch of the Inception module which consists of 1x1 convolutions
    first = GoogLeNet.conv_module(x, num1x1, 1, 1, (1, 1), chanDim, reg = reg, name = stage + "_first")
    
    # define the second branch of the Inception module which consists of 1x1 and 3x3 convolutions
    second = GoogLeNet.conv_module(x, num3x3Reduce, 1, 1, (1, 1), chanDim, reg = reg, name = stage + "_second1")
    second = GoogLeNet.conv_module(second, num3x3, 3, 3, (1, 1), chanDim, reg = reg, name = stage + "_second2")
    
    # define the third branch of the Inception module which are both 1x1 and 5x5 convolutions
    third = GoogLeNet.conv_module(x, num5x5Reduce, 1, 1, (1, 1), chanDim, reg = reg, name = stage + "_third1")
    third = GoogLeNet.conv_module(third, num5x5, 5, 5, (1, 1), chanDim, reg = reg, name = stage + "_third2")
    
    # define the fourth branch of the Inception module which is the POOL projection
    fourth = MaxPooling2D((3, 3), strides = (1, 1), padding = "same", name = stage + "_pool")(x)
    fourth = GoogLeNet.conv_module(fourth, num1x1Proj, 1, 1, (1, 1), chanDim, reg = reg, name = stage + "_fourth")
    
    # concatenate across the channel dimension
    x = concatenate([first, second, third, fourth], axis = chanDim, name = stage + "_mixed")
    
    # return the block
    return x
  
  @staticmethod
  def build(width, height, depth, classes, reg = 0.0005):
    
    # initialize the input shape to be "channel last" and the channels dimension itself
    inputShape = (height, width, depth)
    chanDim = -1
    
    # if we are using "channel first", update the input shape and channels dimension
    if K.image_data_format() == "channels_first":
      inputShape = (depth, height, width)
      chanDim = 1
    
    # define the model input, followed by a sequence of CONV => POOL => (CONV * 2) => POOL layers
    inputs = Input(shape = inputShape)
    x = GoogLeNet.conv_module(inputs, 64, 7, 7, (2, 2), chanDim, reg = reg, name = "block1")
    x = MaxPooling2D((3, 3), strides = (2, 2), padding = "same", name = "pool1")(x)
    x = BatchNormalization(axis = chanDim, name = "bn1")(x)

    x = GoogLeNet.conv_module(x, 64, 1, 1, (1, 1), chanDim, reg = reg, name = "block2")
    x = GoogLeNet.conv_module(x, 192, 3, 3, (1, 1), chanDim, reg = reg, name = "block3")
    x = BatchNormalization(axis = chanDim, name = "bn2")(x)
    x = MaxPooling2D((3, 3), strides = (2, 2), padding = "same", name = "pool2")(x)
    
    # apply two Inception module followed by a POOL
    x = GoogLeNet.inception_module(x, 64, 96, 128, 16, 32, 32, chanDim, "3a", reg = reg) 
    x = GoogLeNet.inception_module(x, 128, 128, 192, 32, 96, 64, chanDim, "3b", reg = reg)
    x = MaxPooling2D((3, 3), strides = (2, 2), padding = "same", name = "pool3")(x)
    
    # apply five Inception module followed by POOL
    x = GoogLeNet.inception_module(x, 192, 96, 208, 16, 48, 64, chanDim, "4a", reg = reg)
    x = GoogLeNet.inception_module(x, 160, 112, 224, 24, 64, 64, chanDim, "4b", reg = reg)
    x = GoogLeNet.inception_module(x, 128, 128, 256, 24, 64, 64, chanDim, "4c", reg = reg)
    x = GoogLeNet.inception_module(x, 112, 144, 288, 32, 64, 64, chanDim, "4d", reg = reg)
    x = GoogLeNet.inception_module(x, 256, 160, 320, 32, 128, 128, chanDim, "4e", reg = reg)
    x = MaxPooling2D((3, 3), strides = (2, 2), padding = "same", name = "pool4")(x)
    
    # apply last two Inception module
    x = GoogLeNet.inception_module(x, 256, 160, 320, 32, 128, 128, chanDim, "5a", reg = reg)
    x = GoogLeNet.inception_module(x, 384, 192, 384, 48, 128, 128, chanDim, "5b", reg = reg)
    
    # apply a POOL layer (average) followed by dropout
    x = AveragePooling2D((7, 7), name = "pool5")(x)
    x = Dropout(0.4, name = "do")(x)
    
    # softmax classifier
    x = Flatten(name = "flatten")(x)
    x = Dense(classes, kernel_regularizer = l2(reg), name = "labels")(x)
    x = Activation("softmax", name = "softmax")(x)
    
    # create the model
    model = Model(inputs, x, name = "googlenet")
    
    # return the constructed network architecture
    return model

# %%
model = GoogLeNet.build(224, 224, 3, 1000)

# %%
model.summary()
# Out:
# Model: "googlenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv (Conv2D)            (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# block1_bn (BatchNormalization)  (None, 112, 112, 64) 256         block1_conv[0][0]
# __________________________________________________________________________________________________
# block1_act (Activation)         (None, 112, 112, 64) 0           block1_bn[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           block1_act[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 56, 56, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# block2_conv (Conv2D)            (None, 56, 56, 64)   4160        bn1[0][0]
# __________________________________________________________________________________________________
# block2_bn (BatchNormalization)  (None, 56, 56, 64)   256         block2_conv[0][0]
# __________________________________________________________________________________________________
# block2_act (Activation)         (None, 56, 56, 64)   0           block2_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv (Conv2D)            (None, 56, 56, 192)  110784      block2_act[0][0]
# __________________________________________________________________________________________________
# block3_bn (BatchNormalization)  (None, 56, 56, 192)  768         block3_conv[0][0]
# __________________________________________________________________________________________________
# block3_act (Activation)         (None, 56, 56, 192)  0           block3_bn[0][0]
# __________________________________________________________________________________________________
# bn2 (BatchNormalization)        (None, 56, 56, 192)  768         block3_act[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 28, 28, 192)  0           bn2[0][0]
# __________________________________________________________________________________________________
# 3a_second1_conv (Conv2D)        (None, 28, 28, 96)   18528       pool2[0][0]
# __________________________________________________________________________________________________
# 3a_third1_conv (Conv2D)         (None, 28, 28, 16)   3088        pool2[0][0]
# __________________________________________________________________________________________________
# 3a_second1_bn (BatchNormalizati (None, 28, 28, 96)   384         3a_second1_conv[0][0]
# __________________________________________________________________________________________________
# 3a_third1_bn (BatchNormalizatio (None, 28, 28, 16)   64          3a_third1_conv[0][0]
# __________________________________________________________________________________________________
# 3a_second1_act (Activation)     (None, 28, 28, 96)   0           3a_second1_bn[0][0]
# __________________________________________________________________________________________________
# 3a_third1_act (Activation)      (None, 28, 28, 16)   0           3a_third1_bn[0][0]
# __________________________________________________________________________________________________
# 3a_pool (MaxPooling2D)          (None, 28, 28, 192)  0           pool2[0][0]
# __________________________________________________________________________________________________
# 3a_first_conv (Conv2D)          (None, 28, 28, 64)   12352       pool2[0][0]
# __________________________________________________________________________________________________
# 3a_second2_conv (Conv2D)        (None, 28, 28, 128)  110720      3a_second1_act[0][0]
# __________________________________________________________________________________________________
# 3a_third2_conv (Conv2D)         (None, 28, 28, 32)   12832       3a_third1_act[0][0]
# __________________________________________________________________________________________________
# 3a_fourth_conv (Conv2D)         (None, 28, 28, 32)   6176        3a_pool[0][0]
# __________________________________________________________________________________________________
# 3a_first_bn (BatchNormalization (None, 28, 28, 64)   256         3a_first_conv[0][0]
# __________________________________________________________________________________________________
# 3a_second2_bn (BatchNormalizati (None, 28, 28, 128)  512         3a_second2_conv[0][0]
# __________________________________________________________________________________________________
# 3a_third2_bn (BatchNormalizatio (None, 28, 28, 32)   128         3a_third2_conv[0][0]
# __________________________________________________________________________________________________
# 3a_fourth_bn (BatchNormalizatio (None, 28, 28, 32)   128         3a_fourth_conv[0][0]
# __________________________________________________________________________________________________
# 3a_first_act (Activation)       (None, 28, 28, 64)   0           3a_first_bn[0][0]
# __________________________________________________________________________________________________
# 3a_second2_act (Activation)     (None, 28, 28, 128)  0           3a_second2_bn[0][0]
# __________________________________________________________________________________________________
# 3a_third2_act (Activation)      (None, 28, 28, 32)   0           3a_third2_bn[0][0]
# __________________________________________________________________________________________________
# 3a_fourth_act (Activation)      (None, 28, 28, 32)   0           3a_fourth_bn[0][0]
# __________________________________________________________________________________________________
# 3a_mixed (Concatenate)          (None, 28, 28, 256)  0           3a_first_act[0][0]
#                                                                  3a_second2_act[0][0]
#                                                                  3a_third2_act[0][0]
#                                                                  3a_fourth_act[0][0]
# __________________________________________________________________________________________________
# 3b_second1_conv (Conv2D)        (None, 28, 28, 128)  32896       3a_mixed[0][0]
# __________________________________________________________________________________________________
# 3b_third1_conv (Conv2D)         (None, 28, 28, 32)   8224        3a_mixed[0][0]
# __________________________________________________________________________________________________
# 3b_second1_bn (BatchNormalizati (None, 28, 28, 128)  512         3b_second1_conv[0][0]
# __________________________________________________________________________________________________
# 3b_third1_bn (BatchNormalizatio (None, 28, 28, 32)   128         3b_third1_conv[0][0]
# __________________________________________________________________________________________________
# 3b_second1_act (Activation)     (None, 28, 28, 128)  0           3b_second1_bn[0][0]
# __________________________________________________________________________________________________
# 3b_third1_act (Activation)      (None, 28, 28, 32)   0           3b_third1_bn[0][0]
# __________________________________________________________________________________________________
# 3b_pool (MaxPooling2D)          (None, 28, 28, 256)  0           3a_mixed[0][0]
# __________________________________________________________________________________________________
# 3b_first_conv (Conv2D)          (None, 28, 28, 128)  32896       3a_mixed[0][0]
# __________________________________________________________________________________________________
# 3b_second2_conv (Conv2D)        (None, 28, 28, 192)  221376      3b_second1_act[0][0]
# __________________________________________________________________________________________________
# 3b_third2_conv (Conv2D)         (None, 28, 28, 96)   76896       3b_third1_act[0][0]
# __________________________________________________________________________________________________
# 3b_fourth_conv (Conv2D)         (None, 28, 28, 64)   16448       3b_pool[0][0]
# __________________________________________________________________________________________________
# 3b_first_bn (BatchNormalization (None, 28, 28, 128)  512         3b_first_conv[0][0]
# __________________________________________________________________________________________________
# 3b_second2_bn (BatchNormalizati (None, 28, 28, 192)  768         3b_second2_conv[0][0]
# __________________________________________________________________________________________________
# 3b_third2_bn (BatchNormalizatio (None, 28, 28, 96)   384         3b_third2_conv[0][0]
# __________________________________________________________________________________________________
# 3b_fourth_bn (BatchNormalizatio (None, 28, 28, 64)   256         3b_fourth_conv[0][0]
# __________________________________________________________________________________________________
# 3b_first_act (Activation)       (None, 28, 28, 128)  0           3b_first_bn[0][0]
# __________________________________________________________________________________________________
# 3b_second2_act (Activation)     (None, 28, 28, 192)  0           3b_second2_bn[0][0]
# __________________________________________________________________________________________________
# 3b_third2_act (Activation)      (None, 28, 28, 96)   0           3b_third2_bn[0][0]
# __________________________________________________________________________________________________
# 3b_fourth_act (Activation)      (None, 28, 28, 64)   0           3b_fourth_bn[0][0]
# __________________________________________________________________________________________________
# 3b_mixed (Concatenate)          (None, 28, 28, 480)  0           3b_first_act[0][0]
#                                                                  3b_second2_act[0][0]
#                                                                  3b_third2_act[0][0]
#                                                                  3b_fourth_act[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 14, 14, 480)  0           3b_mixed[0][0]
# __________________________________________________________________________________________________
# 4a_second1_conv (Conv2D)        (None, 14, 14, 96)   46176       pool3[0][0]
# __________________________________________________________________________________________________
# 4a_third1_conv (Conv2D)         (None, 14, 14, 16)   7696        pool3[0][0]
# __________________________________________________________________________________________________
# 4a_second1_bn (BatchNormalizati (None, 14, 14, 96)   384         4a_second1_conv[0][0]
# __________________________________________________________________________________________________
# 4a_third1_bn (BatchNormalizatio (None, 14, 14, 16)   64          4a_third1_conv[0][0]
# __________________________________________________________________________________________________
# 4a_second1_act (Activation)     (None, 14, 14, 96)   0           4a_second1_bn[0][0]
# __________________________________________________________________________________________________
# 4a_third1_act (Activation)      (None, 14, 14, 16)   0           4a_third1_bn[0][0]
# __________________________________________________________________________________________________
# 4a_pool (MaxPooling2D)          (None, 14, 14, 480)  0           pool3[0][0]
# __________________________________________________________________________________________________
# 4a_first_conv (Conv2D)          (None, 14, 14, 192)  92352       pool3[0][0]
# __________________________________________________________________________________________________
# 4a_second2_conv (Conv2D)        (None, 14, 14, 208)  179920      4a_second1_act[0][0]
# __________________________________________________________________________________________________
# 4a_third2_conv (Conv2D)         (None, 14, 14, 48)   19248       4a_third1_act[0][0]
# __________________________________________________________________________________________________
# 4a_fourth_conv (Conv2D)         (None, 14, 14, 64)   30784       4a_pool[0][0]
# __________________________________________________________________________________________________
# 4a_first_bn (BatchNormalization (None, 14, 14, 192)  768         4a_first_conv[0][0]
# __________________________________________________________________________________________________
# 4a_second2_bn (BatchNormalizati (None, 14, 14, 208)  832         4a_second2_conv[0][0]
# __________________________________________________________________________________________________
# 4a_third2_bn (BatchNormalizatio (None, 14, 14, 48)   192         4a_third2_conv[0][0]
# __________________________________________________________________________________________________
# 4a_fourth_bn (BatchNormalizatio (None, 14, 14, 64)   256         4a_fourth_conv[0][0]
# __________________________________________________________________________________________________
# 4a_first_act (Activation)       (None, 14, 14, 192)  0           4a_first_bn[0][0]
# __________________________________________________________________________________________________
# 4a_second2_act (Activation)     (None, 14, 14, 208)  0           4a_second2_bn[0][0]
# __________________________________________________________________________________________________
# 4a_third2_act (Activation)      (None, 14, 14, 48)   0           4a_third2_bn[0][0]
# __________________________________________________________________________________________________
# 4a_fourth_act (Activation)      (None, 14, 14, 64)   0           4a_fourth_bn[0][0]
# __________________________________________________________________________________________________
# 4a_mixed (Concatenate)          (None, 14, 14, 512)  0           4a_first_act[0][0]
#                                                                  4a_second2_act[0][0]
#                                                                  4a_third2_act[0][0]
#                                                                  4a_fourth_act[0][0]
# __________________________________________________________________________________________________
# 4b_second1_conv (Conv2D)        (None, 14, 14, 112)  57456       4a_mixed[0][0]
# __________________________________________________________________________________________________
# 4b_third1_conv (Conv2D)         (None, 14, 14, 24)   12312       4a_mixed[0][0]
# __________________________________________________________________________________________________
# 4b_second1_bn (BatchNormalizati (None, 14, 14, 112)  448         4b_second1_conv[0][0]
# __________________________________________________________________________________________________
# 4b_third1_bn (BatchNormalizatio (None, 14, 14, 24)   96          4b_third1_conv[0][0]
# __________________________________________________________________________________________________
# 4b_second1_act (Activation)     (None, 14, 14, 112)  0           4b_second1_bn[0][0]
# __________________________________________________________________________________________________
# 4b_third1_act (Activation)      (None, 14, 14, 24)   0           4b_third1_bn[0][0]
# __________________________________________________________________________________________________
# 4b_pool (MaxPooling2D)          (None, 14, 14, 512)  0           4a_mixed[0][0]
# __________________________________________________________________________________________________
# 4b_first_conv (Conv2D)          (None, 14, 14, 160)  82080       4a_mixed[0][0]
# __________________________________________________________________________________________________
# 4b_second2_conv (Conv2D)        (None, 14, 14, 224)  226016      4b_second1_act[0][0]
# __________________________________________________________________________________________________
# 4b_third2_conv (Conv2D)         (None, 14, 14, 64)   38464       4b_third1_act[0][0]
# __________________________________________________________________________________________________
# 4b_fourth_conv (Conv2D)         (None, 14, 14, 64)   32832       4b_pool[0][0]
# __________________________________________________________________________________________________
# 4b_first_bn (BatchNormalization (None, 14, 14, 160)  640         4b_first_conv[0][0]
# __________________________________________________________________________________________________
# 4b_second2_bn (BatchNormalizati (None, 14, 14, 224)  896         4b_second2_conv[0][0]
# __________________________________________________________________________________________________
# 4b_third2_bn (BatchNormalizatio (None, 14, 14, 64)   256         4b_third2_conv[0][0]
# __________________________________________________________________________________________________
# 4b_fourth_bn (BatchNormalizatio (None, 14, 14, 64)   256         4b_fourth_conv[0][0]
# __________________________________________________________________________________________________
# 4b_first_act (Activation)       (None, 14, 14, 160)  0           4b_first_bn[0][0]
# __________________________________________________________________________________________________
# 4b_second2_act (Activation)     (None, 14, 14, 224)  0           4b_second2_bn[0][0]
# __________________________________________________________________________________________________
# 4b_third2_act (Activation)      (None, 14, 14, 64)   0           4b_third2_bn[0][0]
# __________________________________________________________________________________________________
# 4b_fourth_act (Activation)      (None, 14, 14, 64)   0           4b_fourth_bn[0][0]
# __________________________________________________________________________________________________
# 4b_mixed (Concatenate)          (None, 14, 14, 512)  0           4b_first_act[0][0]
#                                                                  4b_second2_act[0][0]
#                                                                  4b_third2_act[0][0]
#                                                                  4b_fourth_act[0][0]
# __________________________________________________________________________________________________
# 4c_second1_conv (Conv2D)        (None, 14, 14, 128)  65664       4b_mixed[0][0]
# __________________________________________________________________________________________________
# 4c_third1_conv (Conv2D)         (None, 14, 14, 24)   12312       4b_mixed[0][0]
# __________________________________________________________________________________________________
# 4c_second1_bn (BatchNormalizati (None, 14, 14, 128)  512         4c_second1_conv[0][0]
# __________________________________________________________________________________________________
# 4c_third1_bn (BatchNormalizatio (None, 14, 14, 24)   96          4c_third1_conv[0][0]
# __________________________________________________________________________________________________
# 4c_second1_act (Activation)     (None, 14, 14, 128)  0           4c_second1_bn[0][0]
# __________________________________________________________________________________________________
# 4c_third1_act (Activation)      (None, 14, 14, 24)   0           4c_third1_bn[0][0]
# __________________________________________________________________________________________________
# 4c_pool (MaxPooling2D)          (None, 14, 14, 512)  0           4b_mixed[0][0]
# __________________________________________________________________________________________________
# 4c_first_conv (Conv2D)          (None, 14, 14, 128)  65664       4b_mixed[0][0]
# __________________________________________________________________________________________________
# 4c_second2_conv (Conv2D)        (None, 14, 14, 256)  295168      4c_second1_act[0][0]
# __________________________________________________________________________________________________
# 4c_third2_conv (Conv2D)         (None, 14, 14, 64)   38464       4c_third1_act[0][0]
# __________________________________________________________________________________________________
# 4c_fourth_conv (Conv2D)         (None, 14, 14, 64)   32832       4c_pool[0][0]
# __________________________________________________________________________________________________
# 4c_first_bn (BatchNormalization (None, 14, 14, 128)  512         4c_first_conv[0][0]
# __________________________________________________________________________________________________
# 4c_second2_bn (BatchNormalizati (None, 14, 14, 256)  1024        4c_second2_conv[0][0]
# __________________________________________________________________________________________________
# 4c_third2_bn (BatchNormalizatio (None, 14, 14, 64)   256         4c_third2_conv[0][0]
# __________________________________________________________________________________________________
# 4c_fourth_bn (BatchNormalizatio (None, 14, 14, 64)   256         4c_fourth_conv[0][0]
# __________________________________________________________________________________________________
# 4c_first_act (Activation)       (None, 14, 14, 128)  0           4c_first_bn[0][0]
# __________________________________________________________________________________________________
# 4c_second2_act (Activation)     (None, 14, 14, 256)  0           4c_second2_bn[0][0]
# __________________________________________________________________________________________________
# 4c_third2_act (Activation)      (None, 14, 14, 64)   0           4c_third2_bn[0][0]
# __________________________________________________________________________________________________
# 4c_fourth_act (Activation)      (None, 14, 14, 64)   0           4c_fourth_bn[0][0]
# __________________________________________________________________________________________________
# 4c_mixed (Concatenate)          (None, 14, 14, 512)  0           4c_first_act[0][0]
#                                                                  4c_second2_act[0][0]
#                                                                  4c_third2_act[0][0]
#                                                                  4c_fourth_act[0][0]
# __________________________________________________________________________________________________
# 4d_second1_conv (Conv2D)        (None, 14, 14, 144)  73872       4c_mixed[0][0]
# __________________________________________________________________________________________________
# 4d_third1_conv (Conv2D)         (None, 14, 14, 32)   16416       4c_mixed[0][0]
# __________________________________________________________________________________________________
# 4d_second1_bn (BatchNormalizati (None, 14, 14, 144)  576         4d_second1_conv[0][0]
# __________________________________________________________________________________________________
# 4d_third1_bn (BatchNormalizatio (None, 14, 14, 32)   128         4d_third1_conv[0][0]
# __________________________________________________________________________________________________
# 4d_second1_act (Activation)     (None, 14, 14, 144)  0           4d_second1_bn[0][0]
# __________________________________________________________________________________________________
# 4d_third1_act (Activation)      (None, 14, 14, 32)   0           4d_third1_bn[0][0]
# __________________________________________________________________________________________________
# 4d_pool (MaxPooling2D)          (None, 14, 14, 512)  0           4c_mixed[0][0]
# __________________________________________________________________________________________________
# 4d_first_conv (Conv2D)          (None, 14, 14, 112)  57456       4c_mixed[0][0]
# __________________________________________________________________________________________________
# 4d_second2_conv (Conv2D)        (None, 14, 14, 288)  373536      4d_second1_act[0][0]
# __________________________________________________________________________________________________
# 4d_third2_conv (Conv2D)         (None, 14, 14, 64)   51264       4d_third1_act[0][0]
# __________________________________________________________________________________________________
# 4d_fourth_conv (Conv2D)         (None, 14, 14, 64)   32832       4d_pool[0][0]
# __________________________________________________________________________________________________
# 4d_first_bn (BatchNormalization (None, 14, 14, 112)  448         4d_first_conv[0][0]
# __________________________________________________________________________________________________
# 4d_second2_bn (BatchNormalizati (None, 14, 14, 288)  1152        4d_second2_conv[0][0]
# __________________________________________________________________________________________________
# 4d_third2_bn (BatchNormalizatio (None, 14, 14, 64)   256         4d_third2_conv[0][0]
# __________________________________________________________________________________________________
# 4d_fourth_bn (BatchNormalizatio (None, 14, 14, 64)   256         4d_fourth_conv[0][0]
# __________________________________________________________________________________________________
# 4d_first_act (Activation)       (None, 14, 14, 112)  0           4d_first_bn[0][0]
# __________________________________________________________________________________________________
# 4d_second2_act (Activation)     (None, 14, 14, 288)  0           4d_second2_bn[0][0]
# __________________________________________________________________________________________________
# 4d_third2_act (Activation)      (None, 14, 14, 64)   0           4d_third2_bn[0][0]
# __________________________________________________________________________________________________
# 4d_fourth_act (Activation)      (None, 14, 14, 64)   0           4d_fourth_bn[0][0]
# __________________________________________________________________________________________________
# 4d_mixed (Concatenate)          (None, 14, 14, 528)  0           4d_first_act[0][0]
#                                                                  4d_second2_act[0][0]
#                                                                  4d_third2_act[0][0]
#                                                                  4d_fourth_act[0][0]
# __________________________________________________________________________________________________
# 4e_second1_conv (Conv2D)        (None, 14, 14, 160)  84640       4d_mixed[0][0]
# __________________________________________________________________________________________________
# 4e_third1_conv (Conv2D)         (None, 14, 14, 32)   16928       4d_mixed[0][0]
# __________________________________________________________________________________________________
# 4e_second1_bn (BatchNormalizati (None, 14, 14, 160)  640         4e_second1_conv[0][0]
# __________________________________________________________________________________________________
# 4e_third1_bn (BatchNormalizatio (None, 14, 14, 32)   128         4e_third1_conv[0][0]
# __________________________________________________________________________________________________
# 4e_second1_act (Activation)     (None, 14, 14, 160)  0           4e_second1_bn[0][0]
# __________________________________________________________________________________________________
# 4e_third1_act (Activation)      (None, 14, 14, 32)   0           4e_third1_bn[0][0]
# __________________________________________________________________________________________________
# 4e_pool (MaxPooling2D)          (None, 14, 14, 528)  0           4d_mixed[0][0]
# __________________________________________________________________________________________________
# 4e_first_conv (Conv2D)          (None, 14, 14, 256)  135424      4d_mixed[0][0]
# __________________________________________________________________________________________________
# 4e_second2_conv (Conv2D)        (None, 14, 14, 320)  461120      4e_second1_act[0][0]
# __________________________________________________________________________________________________
# 4e_third2_conv (Conv2D)         (None, 14, 14, 128)  102528      4e_third1_act[0][0]
# __________________________________________________________________________________________________
# 4e_fourth_conv (Conv2D)         (None, 14, 14, 128)  67712       4e_pool[0][0]
# __________________________________________________________________________________________________
# 4e_first_bn (BatchNormalization (None, 14, 14, 256)  1024        4e_first_conv[0][0]
# __________________________________________________________________________________________________
# 4e_second2_bn (BatchNormalizati (None, 14, 14, 320)  1280        4e_second2_conv[0][0]
# __________________________________________________________________________________________________
# 4e_third2_bn (BatchNormalizatio (None, 14, 14, 128)  512         4e_third2_conv[0][0]
# __________________________________________________________________________________________________
# 4e_fourth_bn (BatchNormalizatio (None, 14, 14, 128)  512         4e_fourth_conv[0][0]
# __________________________________________________________________________________________________
# 4e_first_act (Activation)       (None, 14, 14, 256)  0           4e_first_bn[0][0]
# __________________________________________________________________________________________________
# 4e_second2_act (Activation)     (None, 14, 14, 320)  0           4e_second2_bn[0][0]
# __________________________________________________________________________________________________
# 4e_third2_act (Activation)      (None, 14, 14, 128)  0           4e_third2_bn[0][0]
# __________________________________________________________________________________________________
# 4e_fourth_act (Activation)      (None, 14, 14, 128)  0           4e_fourth_bn[0][0]
# __________________________________________________________________________________________________
# 4e_mixed (Concatenate)          (None, 14, 14, 832)  0           4e_first_act[0][0]
#                                                                  4e_second2_act[0][0]
#                                                                  4e_third2_act[0][0]
#                                                                  4e_fourth_act[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 7, 7, 832)    0           4e_mixed[0][0]
# __________________________________________________________________________________________________
# 5a_second1_conv (Conv2D)        (None, 7, 7, 160)    133280      pool4[0][0]
# __________________________________________________________________________________________________
# 5a_third1_conv (Conv2D)         (None, 7, 7, 32)     26656       pool4[0][0]
# __________________________________________________________________________________________________
# 5a_second1_bn (BatchNormalizati (None, 7, 7, 160)    640         5a_second1_conv[0][0]
# __________________________________________________________________________________________________
# 5a_third1_bn (BatchNormalizatio (None, 7, 7, 32)     128         5a_third1_conv[0][0]
# __________________________________________________________________________________________________
# 5a_second1_act (Activation)     (None, 7, 7, 160)    0           5a_second1_bn[0][0]
# __________________________________________________________________________________________________
# 5a_third1_act (Activation)      (None, 7, 7, 32)     0           5a_third1_bn[0][0]
# __________________________________________________________________________________________________
# 5a_pool (MaxPooling2D)          (None, 7, 7, 832)    0           pool4[0][0]
# __________________________________________________________________________________________________
# 5a_first_conv (Conv2D)          (None, 7, 7, 256)    213248      pool4[0][0]
# __________________________________________________________________________________________________
# 5a_second2_conv (Conv2D)        (None, 7, 7, 320)    461120      5a_second1_act[0][0]
# __________________________________________________________________________________________________
# 5a_third2_conv (Conv2D)         (None, 7, 7, 128)    102528      5a_third1_act[0][0]
# __________________________________________________________________________________________________
# 5a_fourth_conv (Conv2D)         (None, 7, 7, 128)    106624      5a_pool[0][0]
# __________________________________________________________________________________________________
# 5a_first_bn (BatchNormalization (None, 7, 7, 256)    1024        5a_first_conv[0][0]
# __________________________________________________________________________________________________
# 5a_second2_bn (BatchNormalizati (None, 7, 7, 320)    1280        5a_second2_conv[0][0]
# __________________________________________________________________________________________________
# 5a_third2_bn (BatchNormalizatio (None, 7, 7, 128)    512         5a_third2_conv[0][0]
# __________________________________________________________________________________________________
# 5a_fourth_bn (BatchNormalizatio (None, 7, 7, 128)    512         5a_fourth_conv[0][0]
# __________________________________________________________________________________________________
# 5a_first_act (Activation)       (None, 7, 7, 256)    0           5a_first_bn[0][0]
# __________________________________________________________________________________________________
# 5a_second2_act (Activation)     (None, 7, 7, 320)    0           5a_second2_bn[0][0]
# __________________________________________________________________________________________________
# 5a_third2_act (Activation)      (None, 7, 7, 128)    0           5a_third2_bn[0][0]
# __________________________________________________________________________________________________
# 5a_fourth_act (Activation)      (None, 7, 7, 128)    0           5a_fourth_bn[0][0]
# __________________________________________________________________________________________________
# 5a_mixed (Concatenate)          (None, 7, 7, 832)    0           5a_first_act[0][0]
#                                                                  5a_second2_act[0][0]
#                                                                  5a_third2_act[0][0]
#                                                                  5a_fourth_act[0][0]
# __________________________________________________________________________________________________
# 5b_second1_conv (Conv2D)        (None, 7, 7, 192)    159936      5a_mixed[0][0]
# __________________________________________________________________________________________________
# 5b_third1_conv (Conv2D)         (None, 7, 7, 48)     39984       5a_mixed[0][0]
# __________________________________________________________________________________________________
# 5b_second1_bn (BatchNormalizati (None, 7, 7, 192)    768         5b_second1_conv[0][0]
# __________________________________________________________________________________________________
# 5b_third1_bn (BatchNormalizatio (None, 7, 7, 48)     192         5b_third1_conv[0][0]
# __________________________________________________________________________________________________
# 5b_second1_act (Activation)     (None, 7, 7, 192)    0           5b_second1_bn[0][0]
# __________________________________________________________________________________________________
# 5b_third1_act (Activation)      (None, 7, 7, 48)     0           5b_third1_bn[0][0]
# __________________________________________________________________________________________________
# 5b_pool (MaxPooling2D)          (None, 7, 7, 832)    0           5a_mixed[0][0]
# __________________________________________________________________________________________________
# 5b_first_conv (Conv2D)          (None, 7, 7, 384)    319872      5a_mixed[0][0]
# __________________________________________________________________________________________________
# 5b_second2_conv (Conv2D)        (None, 7, 7, 384)    663936      5b_second1_act[0][0]
# __________________________________________________________________________________________________
# 5b_third2_conv (Conv2D)         (None, 7, 7, 128)    153728      5b_third1_act[0][0]
# __________________________________________________________________________________________________
# 5b_fourth_conv (Conv2D)         (None, 7, 7, 128)    106624      5b_pool[0][0]
# __________________________________________________________________________________________________
# 5b_first_bn (BatchNormalization (None, 7, 7, 384)    1536        5b_first_conv[0][0]
# __________________________________________________________________________________________________
# 5b_second2_bn (BatchNormalizati (None, 7, 7, 384)    1536        5b_second2_conv[0][0]
# __________________________________________________________________________________________________
# 5b_third2_bn (BatchNormalizatio (None, 7, 7, 128)    512         5b_third2_conv[0][0]
# __________________________________________________________________________________________________
# 5b_fourth_bn (BatchNormalizatio (None, 7, 7, 128)    512         5b_fourth_conv[0][0]
# __________________________________________________________________________________________________
# 5b_first_act (Activation)       (None, 7, 7, 384)    0           5b_first_bn[0][0]
# __________________________________________________________________________________________________
# 5b_second2_act (Activation)     (None, 7, 7, 384)    0           5b_second2_bn[0][0]
# __________________________________________________________________________________________________
# 5b_third2_act (Activation)      (None, 7, 7, 128)    0           5b_third2_bn[0][0]
# __________________________________________________________________________________________________
# 5b_fourth_act (Activation)      (None, 7, 7, 128)    0           5b_fourth_bn[0][0]
# __________________________________________________________________________________________________
# 5b_mixed (Concatenate)          (None, 7, 7, 1024)   0           5b_first_act[0][0]
#                                                                  5b_second2_act[0][0]
#                                                                  5b_third2_act[0][0]
#                                                                  5b_fourth_act[0][0]
# __________________________________________________________________________________________________
# pool5 (AveragePooling2D)        (None, 1, 1, 1024)   0           5b_mixed[0][0]
# __________________________________________________________________________________________________
# do (Dropout)                    (None, 1, 1, 1024)   0           pool5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           do[0][0]
# __________________________________________________________________________________________________
# labels (Dense)                  (None, 1000)         1025000     flatten[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 1000)         0           labels[0][0]
# ==================================================================================================
# Total params: 7,028,696
# Trainable params: 7,013,624
# Non-trainable params: 15,072
# __________________________________________________________________________________________________
