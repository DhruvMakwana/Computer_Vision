# %%
# importing libraries
from keras.layers import Input, Add, add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D
from keras.models import Model
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
def identity_block(input_tensor, kernel_size, filters, stage, block):
  """
    The identity_block is the block that has no conv layer at shortcut
    
    Arguments:
      input_tensor -- input tensor
      kernel_size: defualt 3, the kernel size of middle conv layer at main path
      filters: list of integers, the nb_filters of 3 conv layer at main path
      stage: integer, current stage label, used for generating layer names
      block: 'a','b'..., current block label, used for generating layer names
    
    Returns:
      X -- output of the identity block
    """
  eps = 1.1e-5

  # Retrieve Filters
  filters1, filters2, filters3 = filters

  # defining name basis
  conv_name_base = 'res152' + str(stage) + block + '_branch'
  bn_name_base = 'bn' + str(stage) + block + '_branch'

  chanDim = 3
  if K.image_data_format() == "channels_first":
    inputShape = (depth, height, width)
    chanDim = 1
  
  # First component of main path
  X = Conv2D(filters = filters1, kernel_size = (1, 1), name = conv_name_base + '2a')(input_tensor)
  X = BatchNormalization(epsilon = eps, axis = chanDim, name = bn_name_base + '2a')(X)
  X = Activation('relu', name = conv_name_base + '2a_relu')(X)
  
  # Second component of main path 
  X = ZeroPadding2D(padding = (1, 1), name = conv_name_base + '2b_zeropadding')(X)
  X = Conv2D(filters = filters2, kernel_size = (kernel_size, kernel_size), name = conv_name_base + '2b')(X)
  X = BatchNormalization(epsilon = eps, axis = chanDim, name = bn_name_base + '2b')(X)
  X = Activation('relu', name = conv_name_base + '2b_relu')(X)
  
  # Third component of main path 
  X = Conv2D(filters = filters3, kernel_size = (1, 1), name = conv_name_base + '2c')(X)
  X = BatchNormalization(epsilon = eps, axis = chanDim, name = bn_name_base + '2c')(X)

  # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
  X = Add()([X, input_tensor])
  X = Activation('relu', name = 'res152' + str(stage) + block + '_relu')(X)
  
  return X

# %%
def convolutional_block(input_tensor, kernel_size, filters, stage, block, strides = (2, 2)):
  """
    conv_block is the block that has a conv layer at shortcut
    
    Arguments:
      input_tensor: input tensor
      kernel_size: defualt 3, the kernel size of middle conv layer at main path
      filters: list of integers, the nb_filters of 3 conv layer at main path
      stage: integer, current stage label, used for generating layer names
      block: 'a','b'..., current block label, used for generating layer names
      strides: Integer, specifying the stride to be used
    
    Returns:
      X: output of the convolutional block
  """
  chanDim = 3
  eps = 1.1e-5
  
  if K.image_data_format() == "channels_first":
    inputShape = (depth, height, width)
    chanDim = 1
  
  # defining name basis
  conv_name_base = 'res152' + str(stage) + block + '_branch'
  bn_name_base = 'bn' + str(stage) + block + '_branch'
  
  # Retrieve Filters
  filters1, filters2, filters3 = filters
  
  ##### MAIN PATH #####
  # First component of main path 
  X = Conv2D(filters = filters1, kernel_size = (1, 1), strides = strides, name = conv_name_base + '2a')(input_tensor)
  X = BatchNormalization(epsilon = eps, axis = chanDim, name = bn_name_base + '2a')(X)
  X = Activation('relu', name = conv_name_base + '2a_relu')(X)
  
  # Second component of main path 
  X = ZeroPadding2D(padding = (1, 1), name = conv_name_base + '2b_zeropadding')(X)
  X = Conv2D(filters = filters2, kernel_size = (kernel_size, kernel_size), name = conv_name_base + '2b')(X)
  X = BatchNormalization(epsilon = eps, axis = chanDim, name = bn_name_base + '2b')(X)
  X = Activation('relu', name = conv_name_base + "2b_relu")(X)
  
  # Third component of main path 
  X = Conv2D(filters = filters3, kernel_size = (1, 1), name = conv_name_base + '2c')(X)
  X = BatchNormalization(epsilon = eps, axis = chanDim, name = bn_name_base + '2c')(X)
  
  ##### SHORTCUT PATH #### 
  X_shortcut = Conv2D(filters = filters3, kernel_size = (1, 1), strides = strides, name = conv_name_base + '1')(input_tensor)
  X_shortcut = BatchNormalization(epsilon = eps, axis = chanDim, name = bn_name_base + '1')(X_shortcut)
  
  # Final step: Add shortcut value to main path, and pass it through a RELU activation
  X = Add()([X, X_shortcut])
  X = Activation('relu', name = "res152" + str(stage) + block + "_relu")(X) 
  
  return X

# %%
class ResNet152:
  @staticmethod
  def build(input_shape = (224, 224, 3), classes = 1000):
    """
      Implementation of the popular ResNet50 the following architecture:
      CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3 -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER
    
      Arguments:
        input_shape -- shape of the images of the dataset
        classes -- integer, number of classes

      Returns:
        model -- a Model() instance in Keras
    """
    eps = 1.1e-5
    chanDim = 3
    X_input = Input(shape = input_shape, name = "data")
    
    if K.image_data_format() == "channels_first":
      inputShape = (depth, height, width)
      X_input = Input(shape = input_shape, name = "data")
      chanDim = 1
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(shape = input_shape)
    
    # Zero-Padding
    X = ZeroPadding2D(padding = (3, 3), name = 'conv1_zeropadding')(X_input)
    
    # Stage 1
    X = Conv2D(filters = 64, kernel_size = (7, 7), strides = (2, 2), name = 'conv1')(X)
    X = BatchNormalization(epsilon = eps, axis = chanDim, name = 'bn_conv1')(X)
    X = Activation('relu', name = "conv1_relu")(X)
    X = ZeroPadding2D(padding = (1, 1), name = 'pool1_pad')(X)
    X = MaxPooling2D(pool_size = (3, 3), strides = (2, 2), name = 'pool1')(X)
    
    # Stage 2
    X = convolutional_block(input_tensor = X, kernel_size = 3, filters = [64, 64, 256], stage = 2, block = 'a', strides = (1, 1))
    X = identity_block(input_tensor = X, kernel_size = 3, filters = [64, 64, 256], stage = 2, block = 'b')
    X = identity_block(input_tensor = X, kernel_size = 3, filters = [64, 64, 256], stage = 2, block = 'c')
    
    # Stage 3 
    X = convolutional_block(input_tensor = X, kernel_size = 3, filters = [128, 128, 512], stage = 3, block = 'a')
    for i in range(1, 8):
      X = identity_block(input_tensor = X, kernel_size = 3, filters = [128, 128, 512], stage = 3, block = 'b' + str(i))
    
    # Stage 4
    X = convolutional_block(input_tensor = X, kernel_size = 3, filters = [256, 256, 1024], stage = 4, block='a')
    for i in range(1, 36):
      X = identity_block(input_tensor = X, kernel_size = 3, filters = [256, 256, 1024], stage = 4, block = 'b' + str(i))
    
    
    # Stage 5
    X = convolutional_block(input_tensor = X, kernel_size = 3, filters = [512, 512, 2048], stage = 5, block = 'a')
    X = identity_block(input_tensor = X, kernel_size = 3, filters = [512, 512, 2048], stage = 5, block = 'b')
    X = identity_block(input_tensor = X, kernel_size = 3, filters = [512, 512, 2048], stage = 5, block = 'c')
    
    # AVGPOOL 
    X = AveragePooling2D(pool_size = (7, 7), name = 'avg_pool')(X)
    
    ### END CODE HERE ###
    
    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation = 'softmax', name = 'fc' + str(classes))(X)
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name = "ResNet152")
    return model

# %%
model = ResNet152.build(input_shape = (224, 224, 3), classes = 1000)
model.summary()
# Out:
# Model: "ResNet152"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_zeropadding (ZeroPadding2 (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_zeropadding[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res1522a_branch2a (Conv2D)      (None, 56, 56, 64)   4160        pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res1522a_branch2a[0][0]
# __________________________________________________________________________________________________
# res1522a_branch2a_relu (Activat (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res1522a_branch2b_zeropadding ( (None, 58, 58, 64)   0           res1522a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1522a_branch2b (Conv2D)      (None, 56, 56, 64)   36928       res1522a_branch2b_zeropadding[0][
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res1522a_branch2b[0][0]
# __________________________________________________________________________________________________
# res1522a_branch2b_relu (Activat (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res1522a_branch2c (Conv2D)      (None, 56, 56, 256)  16640       res1522a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res1522a_branch1 (Conv2D)       (None, 56, 56, 256)  16640       pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res1522a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res1522a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res1522a_relu (Activation)      (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res1522b_branch2a (Conv2D)      (None, 56, 56, 64)   16448       res1522a_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res1522b_branch2a[0][0]
# __________________________________________________________________________________________________
# res1522b_branch2a_relu (Activat (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res1522b_branch2b_zeropadding ( (None, 58, 58, 64)   0           res1522b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1522b_branch2b (Conv2D)      (None, 56, 56, 64)   36928       res1522b_branch2b_zeropadding[0][
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res1522b_branch2b[0][0]
# __________________________________________________________________________________________________
# res1522b_branch2b_relu (Activat (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res1522b_branch2c (Conv2D)      (None, 56, 56, 256)  16640       res1522b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res1522b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  res1522a_relu[0][0]
# __________________________________________________________________________________________________
# res1522b_relu (Activation)      (None, 56, 56, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res1522c_branch2a (Conv2D)      (None, 56, 56, 64)   16448       res1522b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res1522c_branch2a[0][0]
# __________________________________________________________________________________________________
# res1522c_branch2a_relu (Activat (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res1522c_branch2b_zeropadding ( (None, 58, 58, 64)   0           res1522c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1522c_branch2b (Conv2D)      (None, 56, 56, 64)   36928       res1522c_branch2b_zeropadding[0][
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res1522c_branch2b[0][0]
# __________________________________________________________________________________________________
# res1522c_branch2b_relu (Activat (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res1522c_branch2c (Conv2D)      (None, 56, 56, 256)  16640       res1522c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res1522c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  res1522b_relu[0][0]
# __________________________________________________________________________________________________
# res1522c_relu (Activation)      (None, 56, 56, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res1523a_branch2a (Conv2D)      (None, 28, 28, 128)  32896       res1522c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res1523a_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523a_branch2a_relu (Activat (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523a_branch2b_zeropadding ( (None, 30, 30, 128)  0           res1523a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1523a_branch2b (Conv2D)      (None, 28, 28, 128)  147584      res1523a_branch2b_zeropadding[0][
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res1523a_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523a_branch2b_relu (Activat (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523a_branch2c (Conv2D)      (None, 28, 28, 512)  66048       res1523a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res1523a_branch1 (Conv2D)       (None, 28, 28, 512)  131584      res1522c_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res1523a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res1523a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res1523a_relu (Activation)      (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res1523b1_branch2a (Conv2D)     (None, 28, 28, 128)  65664       res1523a_relu[0][0]
# __________________________________________________________________________________________________
# bn3b1_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res1523b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b1_branch2a_relu (Activa (None, 28, 28, 128)  0           bn3b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b1_branch2b_zeropadding  (None, 30, 30, 128)  0           res1523b1_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1523b1_branch2b (Conv2D)     (None, 28, 28, 128)  147584      res1523b1_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn3b1_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res1523b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b1_branch2b_relu (Activa (None, 28, 28, 128)  0           bn3b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b1_branch2c (Conv2D)     (None, 28, 28, 512)  66048       res1523b1_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b1_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res1523b1_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           bn3b1_branch2c[0][0]
#                                                                  res1523a_relu[0][0]
# __________________________________________________________________________________________________
# res1523b1_relu (Activation)     (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res1523b2_branch2a (Conv2D)     (None, 28, 28, 128)  65664       res1523b1_relu[0][0]
# __________________________________________________________________________________________________
# bn3b2_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res1523b2_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b2_branch2a_relu (Activa (None, 28, 28, 128)  0           bn3b2_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b2_branch2b_zeropadding  (None, 30, 30, 128)  0           res1523b2_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1523b2_branch2b (Conv2D)     (None, 28, 28, 128)  147584      res1523b2_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn3b2_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res1523b2_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b2_branch2b_relu (Activa (None, 28, 28, 128)  0           bn3b2_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b2_branch2c (Conv2D)     (None, 28, 28, 512)  66048       res1523b2_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b2_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res1523b2_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           bn3b2_branch2c[0][0]
#                                                                  res1523b1_relu[0][0]
# __________________________________________________________________________________________________
# res1523b2_relu (Activation)     (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res1523b3_branch2a (Conv2D)     (None, 28, 28, 128)  65664       res1523b2_relu[0][0]
# __________________________________________________________________________________________________
# bn3b3_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res1523b3_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b3_branch2a_relu (Activa (None, 28, 28, 128)  0           bn3b3_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b3_branch2b_zeropadding  (None, 30, 30, 128)  0           res1523b3_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1523b3_branch2b (Conv2D)     (None, 28, 28, 128)  147584      res1523b3_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn3b3_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res1523b3_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b3_branch2b_relu (Activa (None, 28, 28, 128)  0           bn3b3_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b3_branch2c (Conv2D)     (None, 28, 28, 512)  66048       res1523b3_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b3_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res1523b3_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 512)  0           bn3b3_branch2c[0][0]
#                                                                  res1523b2_relu[0][0]
# __________________________________________________________________________________________________
# res1523b3_relu (Activation)     (None, 28, 28, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res1523b4_branch2a (Conv2D)     (None, 28, 28, 128)  65664       res1523b3_relu[0][0]
# __________________________________________________________________________________________________
# bn3b4_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res1523b4_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b4_branch2a_relu (Activa (None, 28, 28, 128)  0           bn3b4_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b4_branch2b_zeropadding  (None, 30, 30, 128)  0           res1523b4_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1523b4_branch2b (Conv2D)     (None, 28, 28, 128)  147584      res1523b4_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn3b4_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res1523b4_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b4_branch2b_relu (Activa (None, 28, 28, 128)  0           bn3b4_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b4_branch2c (Conv2D)     (None, 28, 28, 512)  66048       res1523b4_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b4_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res1523b4_branch2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 28, 28, 512)  0           bn3b4_branch2c[0][0]
#                                                                  res1523b3_relu[0][0]
# __________________________________________________________________________________________________
# res1523b4_relu (Activation)     (None, 28, 28, 512)  0           add_8[0][0]
# __________________________________________________________________________________________________
# res1523b5_branch2a (Conv2D)     (None, 28, 28, 128)  65664       res1523b4_relu[0][0]
# __________________________________________________________________________________________________
# bn3b5_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res1523b5_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b5_branch2a_relu (Activa (None, 28, 28, 128)  0           bn3b5_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b5_branch2b_zeropadding  (None, 30, 30, 128)  0           res1523b5_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1523b5_branch2b (Conv2D)     (None, 28, 28, 128)  147584      res1523b5_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn3b5_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res1523b5_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b5_branch2b_relu (Activa (None, 28, 28, 128)  0           bn3b5_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b5_branch2c (Conv2D)     (None, 28, 28, 512)  66048       res1523b5_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b5_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res1523b5_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 28, 28, 512)  0           bn3b5_branch2c[0][0]
#                                                                  res1523b4_relu[0][0]
# __________________________________________________________________________________________________
# res1523b5_relu (Activation)     (None, 28, 28, 512)  0           add_9[0][0]
# __________________________________________________________________________________________________
# res1523b6_branch2a (Conv2D)     (None, 28, 28, 128)  65664       res1523b5_relu[0][0]
# __________________________________________________________________________________________________
# bn3b6_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res1523b6_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b6_branch2a_relu (Activa (None, 28, 28, 128)  0           bn3b6_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b6_branch2b_zeropadding  (None, 30, 30, 128)  0           res1523b6_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1523b6_branch2b (Conv2D)     (None, 28, 28, 128)  147584      res1523b6_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn3b6_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res1523b6_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b6_branch2b_relu (Activa (None, 28, 28, 128)  0           bn3b6_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b6_branch2c (Conv2D)     (None, 28, 28, 512)  66048       res1523b6_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b6_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res1523b6_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 28, 28, 512)  0           bn3b6_branch2c[0][0]
#                                                                  res1523b5_relu[0][0]
# __________________________________________________________________________________________________
# res1523b6_relu (Activation)     (None, 28, 28, 512)  0           add_10[0][0]
# __________________________________________________________________________________________________
# res1523b7_branch2a (Conv2D)     (None, 28, 28, 128)  65664       res1523b6_relu[0][0]
# __________________________________________________________________________________________________
# bn3b7_branch2a (BatchNormalizat (None, 28, 28, 128)  512         res1523b7_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b7_branch2a_relu (Activa (None, 28, 28, 128)  0           bn3b7_branch2a[0][0]
# __________________________________________________________________________________________________
# res1523b7_branch2b_zeropadding  (None, 30, 30, 128)  0           res1523b7_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1523b7_branch2b (Conv2D)     (None, 28, 28, 128)  147584      res1523b7_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn3b7_branch2b (BatchNormalizat (None, 28, 28, 128)  512         res1523b7_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b7_branch2b_relu (Activa (None, 28, 28, 128)  0           bn3b7_branch2b[0][0]
# __________________________________________________________________________________________________
# res1523b7_branch2c (Conv2D)     (None, 28, 28, 512)  66048       res1523b7_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn3b7_branch2c (BatchNormalizat (None, 28, 28, 512)  2048        res1523b7_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 28, 28, 512)  0           bn3b7_branch2c[0][0]
#                                                                  res1523b6_relu[0][0]
# __________________________________________________________________________________________________
# res1523b7_relu (Activation)     (None, 28, 28, 512)  0           add_11[0][0]
# __________________________________________________________________________________________________
# res1524a_branch2a (Conv2D)      (None, 14, 14, 256)  131328      res1523b7_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res1524a_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524a_branch2a_relu (Activat (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524a_branch2b_zeropadding ( (None, 16, 16, 256)  0           res1524a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524a_branch2b (Conv2D)      (None, 14, 14, 256)  590080      res1524a_branch2b_zeropadding[0][
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res1524a_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524a_branch2b_relu (Activat (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524a_branch2c (Conv2D)      (None, 14, 14, 1024) 263168      res1524a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res1524a_branch1 (Conv2D)       (None, 14, 14, 1024) 525312      res1523b7_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res1524a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res1524a_branch1[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res1524a_relu (Activation)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res1524b1_branch2a (Conv2D)     (None, 14, 14, 256)  262400      res1524a_relu[0][0]
# __________________________________________________________________________________________________
# bn4b1_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res1524b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b1_branch2a_relu (Activa (None, 14, 14, 256)  0           bn4b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b1_branch2b_zeropadding  (None, 16, 16, 256)  0           res1524b1_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b1_branch2b (Conv2D)     (None, 14, 14, 256)  590080      res1524b1_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn4b1_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res1524b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b1_branch2b_relu (Activa (None, 14, 14, 256)  0           bn4b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b1_branch2c (Conv2D)     (None, 14, 14, 1024) 263168      res1524b1_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b1_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res1524b1_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 1024) 0           bn4b1_branch2c[0][0]
#                                                                  res1524a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b1_relu (Activation)     (None, 14, 14, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res1524b2_branch2a (Conv2D)     (None, 14, 14, 256)  262400      res1524b1_relu[0][0]
# __________________________________________________________________________________________________
# bn4b2_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res1524b2_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b2_branch2a_relu (Activa (None, 14, 14, 256)  0           bn4b2_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b2_branch2b_zeropadding  (None, 16, 16, 256)  0           res1524b2_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b2_branch2b (Conv2D)     (None, 14, 14, 256)  590080      res1524b2_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn4b2_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res1524b2_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b2_branch2b_relu (Activa (None, 14, 14, 256)  0           bn4b2_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b2_branch2c (Conv2D)     (None, 14, 14, 1024) 263168      res1524b2_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b2_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res1524b2_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 14, 14, 1024) 0           bn4b2_branch2c[0][0]
#                                                                  res1524b1_relu[0][0]
# __________________________________________________________________________________________________
# res1524b2_relu (Activation)     (None, 14, 14, 1024) 0           add_14[0][0]
# __________________________________________________________________________________________________
# res1524b3_branch2a (Conv2D)     (None, 14, 14, 256)  262400      res1524b2_relu[0][0]
# __________________________________________________________________________________________________
# bn4b3_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res1524b3_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b3_branch2a_relu (Activa (None, 14, 14, 256)  0           bn4b3_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b3_branch2b_zeropadding  (None, 16, 16, 256)  0           res1524b3_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b3_branch2b (Conv2D)     (None, 14, 14, 256)  590080      res1524b3_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn4b3_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res1524b3_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b3_branch2b_relu (Activa (None, 14, 14, 256)  0           bn4b3_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b3_branch2c (Conv2D)     (None, 14, 14, 1024) 263168      res1524b3_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b3_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res1524b3_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 14, 14, 1024) 0           bn4b3_branch2c[0][0]
#                                                                  res1524b2_relu[0][0]
# __________________________________________________________________________________________________
# res1524b3_relu (Activation)     (None, 14, 14, 1024) 0           add_15[0][0]
# __________________________________________________________________________________________________
# res1524b4_branch2a (Conv2D)     (None, 14, 14, 256)  262400      res1524b3_relu[0][0]
# __________________________________________________________________________________________________
# bn4b4_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res1524b4_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b4_branch2a_relu (Activa (None, 14, 14, 256)  0           bn4b4_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b4_branch2b_zeropadding  (None, 16, 16, 256)  0           res1524b4_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b4_branch2b (Conv2D)     (None, 14, 14, 256)  590080      res1524b4_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn4b4_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res1524b4_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b4_branch2b_relu (Activa (None, 14, 14, 256)  0           bn4b4_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b4_branch2c (Conv2D)     (None, 14, 14, 1024) 263168      res1524b4_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b4_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res1524b4_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 14, 14, 1024) 0           bn4b4_branch2c[0][0]
#                                                                  res1524b3_relu[0][0]
# __________________________________________________________________________________________________
# res1524b4_relu (Activation)     (None, 14, 14, 1024) 0           add_16[0][0]
# __________________________________________________________________________________________________
# res1524b5_branch2a (Conv2D)     (None, 14, 14, 256)  262400      res1524b4_relu[0][0]
# __________________________________________________________________________________________________
# bn4b5_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res1524b5_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b5_branch2a_relu (Activa (None, 14, 14, 256)  0           bn4b5_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b5_branch2b_zeropadding  (None, 16, 16, 256)  0           res1524b5_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b5_branch2b (Conv2D)     (None, 14, 14, 256)  590080      res1524b5_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn4b5_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res1524b5_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b5_branch2b_relu (Activa (None, 14, 14, 256)  0           bn4b5_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b5_branch2c (Conv2D)     (None, 14, 14, 1024) 263168      res1524b5_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b5_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res1524b5_branch2c[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 14, 14, 1024) 0           bn4b5_branch2c[0][0]
#                                                                  res1524b4_relu[0][0]
# __________________________________________________________________________________________________
# res1524b5_relu (Activation)     (None, 14, 14, 1024) 0           add_17[0][0]
# __________________________________________________________________________________________________
# res1524b6_branch2a (Conv2D)     (None, 14, 14, 256)  262400      res1524b5_relu[0][0]
# __________________________________________________________________________________________________
# bn4b6_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res1524b6_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b6_branch2a_relu (Activa (None, 14, 14, 256)  0           bn4b6_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b6_branch2b_zeropadding  (None, 16, 16, 256)  0           res1524b6_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b6_branch2b (Conv2D)     (None, 14, 14, 256)  590080      res1524b6_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn4b6_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res1524b6_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b6_branch2b_relu (Activa (None, 14, 14, 256)  0           bn4b6_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b6_branch2c (Conv2D)     (None, 14, 14, 1024) 263168      res1524b6_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b6_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res1524b6_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 14, 14, 1024) 0           bn4b6_branch2c[0][0]
#                                                                  res1524b5_relu[0][0]
# __________________________________________________________________________________________________
# res1524b6_relu (Activation)     (None, 14, 14, 1024) 0           add_18[0][0]
# __________________________________________________________________________________________________
# res1524b7_branch2a (Conv2D)     (None, 14, 14, 256)  262400      res1524b6_relu[0][0]
# __________________________________________________________________________________________________
# bn4b7_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res1524b7_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b7_branch2a_relu (Activa (None, 14, 14, 256)  0           bn4b7_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b7_branch2b_zeropadding  (None, 16, 16, 256)  0           res1524b7_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b7_branch2b (Conv2D)     (None, 14, 14, 256)  590080      res1524b7_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn4b7_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res1524b7_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b7_branch2b_relu (Activa (None, 14, 14, 256)  0           bn4b7_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b7_branch2c (Conv2D)     (None, 14, 14, 1024) 263168      res1524b7_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b7_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res1524b7_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 14, 14, 1024) 0           bn4b7_branch2c[0][0]
#                                                                  res1524b6_relu[0][0]
# __________________________________________________________________________________________________
# res1524b7_relu (Activation)     (None, 14, 14, 1024) 0           add_19[0][0]
# __________________________________________________________________________________________________
# res1524b8_branch2a (Conv2D)     (None, 14, 14, 256)  262400      res1524b7_relu[0][0]
# __________________________________________________________________________________________________
# bn4b8_branch2a (BatchNormalizat (None, 14, 14, 256)  1024        res1524b8_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b8_branch2a_relu (Activa (None, 14, 14, 256)  0           bn4b8_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b8_branch2b_zeropadding  (None, 16, 16, 256)  0           res1524b8_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b8_branch2b (Conv2D)     (None, 14, 14, 256)  590080      res1524b8_branch2b_zeropadding[0]
# __________________________________________________________________________________________________
# bn4b8_branch2b (BatchNormalizat (None, 14, 14, 256)  1024        res1524b8_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b8_branch2b_relu (Activa (None, 14, 14, 256)  0           bn4b8_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b8_branch2c (Conv2D)     (None, 14, 14, 1024) 263168      res1524b8_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b8_branch2c (BatchNormalizat (None, 14, 14, 1024) 4096        res1524b8_branch2c[0][0]
# __________________________________________________________________________________________________
# ...
# res1524b32_branch2b_relu (Activ (None, 14, 14, 256)  0           bn4b32_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b32_branch2c (Conv2D)    (None, 14, 14, 1024) 263168      res1524b32_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b32_branch2c (BatchNormaliza (None, 14, 14, 1024) 4096        res1524b32_branch2c[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 14, 14, 1024) 0           bn4b32_branch2c[0][0]
#                                                                  res1524b31_relu[0][0]
# __________________________________________________________________________________________________
# res1524b32_relu (Activation)    (None, 14, 14, 1024) 0           add_44[0][0]
# __________________________________________________________________________________________________
# res1524b33_branch2a (Conv2D)    (None, 14, 14, 256)  262400      res1524b32_relu[0][0]
# __________________________________________________________________________________________________
# bn4b33_branch2a (BatchNormaliza (None, 14, 14, 256)  1024        res1524b33_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b33_branch2a_relu (Activ (None, 14, 14, 256)  0           bn4b33_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b33_branch2b_zeropadding (None, 16, 16, 256)  0           res1524b33_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b33_branch2b (Conv2D)    (None, 14, 14, 256)  590080      res1524b33_branch2b_zeropadding[0
# __________________________________________________________________________________________________
# bn4b33_branch2b (BatchNormaliza (None, 14, 14, 256)  1024        res1524b33_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b33_branch2b_relu (Activ (None, 14, 14, 256)  0           bn4b33_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b33_branch2c (Conv2D)    (None, 14, 14, 1024) 263168      res1524b33_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b33_branch2c (BatchNormaliza (None, 14, 14, 1024) 4096        res1524b33_branch2c[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 14, 14, 1024) 0           bn4b33_branch2c[0][0]
#                                                                  res1524b32_relu[0][0]
# __________________________________________________________________________________________________
# res1524b33_relu (Activation)    (None, 14, 14, 1024) 0           add_45[0][0]
# __________________________________________________________________________________________________
# res1524b34_branch2a (Conv2D)    (None, 14, 14, 256)  262400      res1524b33_relu[0][0]
# __________________________________________________________________________________________________
# bn4b34_branch2a (BatchNormaliza (None, 14, 14, 256)  1024        res1524b34_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b34_branch2a_relu (Activ (None, 14, 14, 256)  0           bn4b34_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b34_branch2b_zeropadding (None, 16, 16, 256)  0           res1524b34_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b34_branch2b (Conv2D)    (None, 14, 14, 256)  590080      res1524b34_branch2b_zeropadding[0
# __________________________________________________________________________________________________
# bn4b34_branch2b (BatchNormaliza (None, 14, 14, 256)  1024        res1524b34_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b34_branch2b_relu (Activ (None, 14, 14, 256)  0           bn4b34_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b34_branch2c (Conv2D)    (None, 14, 14, 1024) 263168      res1524b34_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b34_branch2c (BatchNormaliza (None, 14, 14, 1024) 4096        res1524b34_branch2c[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 14, 14, 1024) 0           bn4b34_branch2c[0][0]
#                                                                  res1524b33_relu[0][0]
# __________________________________________________________________________________________________
# res1524b34_relu (Activation)    (None, 14, 14, 1024) 0           add_46[0][0]
# __________________________________________________________________________________________________
# res1524b35_branch2a (Conv2D)    (None, 14, 14, 256)  262400      res1524b34_relu[0][0]
# __________________________________________________________________________________________________
# bn4b35_branch2a (BatchNormaliza (None, 14, 14, 256)  1024        res1524b35_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b35_branch2a_relu (Activ (None, 14, 14, 256)  0           bn4b35_branch2a[0][0]
# __________________________________________________________________________________________________
# res1524b35_branch2b_zeropadding (None, 16, 16, 256)  0           res1524b35_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1524b35_branch2b (Conv2D)    (None, 14, 14, 256)  590080      res1524b35_branch2b_zeropadding[0
# __________________________________________________________________________________________________
# bn4b35_branch2b (BatchNormaliza (None, 14, 14, 256)  1024        res1524b35_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b35_branch2b_relu (Activ (None, 14, 14, 256)  0           bn4b35_branch2b[0][0]
# __________________________________________________________________________________________________
# res1524b35_branch2c (Conv2D)    (None, 14, 14, 1024) 263168      res1524b35_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn4b35_branch2c (BatchNormaliza (None, 14, 14, 1024) 4096        res1524b35_branch2c[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 14, 14, 1024) 0           bn4b35_branch2c[0][0]
#                                                                  res1524b34_relu[0][0]
# __________________________________________________________________________________________________
# res1524b35_relu (Activation)    (None, 14, 14, 1024) 0           add_47[0][0]
# __________________________________________________________________________________________________
# res1525a_branch2a (Conv2D)      (None, 7, 7, 512)    524800      res1524b35_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res1525a_branch2a[0][0]
# __________________________________________________________________________________________________
# res1525a_branch2a_relu (Activat (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res1525a_branch2b_zeropadding ( (None, 9, 9, 512)    0           res1525a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1525a_branch2b (Conv2D)      (None, 7, 7, 512)    2359808     res1525a_branch2b_zeropadding[0][
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res1525a_branch2b[0][0]
# __________________________________________________________________________________________________
# res1525a_branch2b_relu (Activat (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res1525a_branch2c (Conv2D)      (None, 7, 7, 2048)   1050624     res1525a_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# res1525a_branch1 (Conv2D)       (None, 7, 7, 2048)   2099200     res1524b35_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res1525a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res1525a_branch1[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# res1525a_relu (Activation)      (None, 7, 7, 2048)   0           add_48[0][0]
# __________________________________________________________________________________________________
# res1525b_branch2a (Conv2D)      (None, 7, 7, 512)    1049088     res1525a_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res1525b_branch2a[0][0]
# __________________________________________________________________________________________________
# res1525b_branch2a_relu (Activat (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res1525b_branch2b_zeropadding ( (None, 9, 9, 512)    0           res1525b_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1525b_branch2b (Conv2D)      (None, 7, 7, 512)    2359808     res1525b_branch2b_zeropadding[0][
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res1525b_branch2b[0][0]
# __________________________________________________________________________________________________
# res1525b_branch2b_relu (Activat (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res1525b_branch2c (Conv2D)      (None, 7, 7, 2048)   1050624     res1525b_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res1525b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  res1525a_relu[0][0]
# __________________________________________________________________________________________________
# res1525b_relu (Activation)      (None, 7, 7, 2048)   0           add_49[0][0]
# __________________________________________________________________________________________________
# res1525c_branch2a (Conv2D)      (None, 7, 7, 512)    1049088     res1525b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res1525c_branch2a[0][0]
# __________________________________________________________________________________________________
# res1525c_branch2a_relu (Activat (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res1525c_branch2b_zeropadding ( (None, 9, 9, 512)    0           res1525c_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res1525c_branch2b (Conv2D)      (None, 7, 7, 512)    2359808     res1525c_branch2b_zeropadding[0][
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res1525c_branch2b[0][0]
# __________________________________________________________________________________________________
# res1525c_branch2b_relu (Activat (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res1525c_branch2c (Conv2D)      (None, 7, 7, 2048)   1050624     res1525c_branch2b_relu[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res1525c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  res1525b_relu[0][0]
# __________________________________________________________________________________________________
# res1525c_relu (Activation)      (None, 7, 7, 2048)   0           add_50[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           res1525c_relu[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 1000)         2049000     flatten_1[0][0]
# ==================================================================================================
# Total params: 60,419,944
# Trainable params: 60,268,520
# Non-trainable params: 151,424
# __________________________________________________________________________________________________
